# %%
import pandas as pd
import numpy as np

# %%
data = {
    'age': [25, np.nan, 30, 22, np.nan, 28],
    'salary': [50000, 60000, np.nan, 52000, 58000, np.nan],
    'department': ['HR', 'IT', np.nan, 'Finance', 'IT', 'HR'],
    'experience': [2, 5, np.nan, 1, 4, np.nan]
}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#     age   salary department  experience
# 0  25.0  50000.0         HR         2.0
# 1   NaN  60000.0         IT         5.0
# 2  30.0      NaN        NaN         NaN
# 3  22.0  52000.0    Finance         1.0
# 4   NaN  58000.0         IT         4.0
# 5  28.0      NaN         HR         NaN

# %%
df.isnull().sum()
# Out:
# age           2
# salary        2
# department    1
# experience    2
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# age           33.333333
# salary        33.333333
# department    16.666667
# experience    33.333333
# dtype: float64

# %%
data = {
    'age': [25, np.nan, 30, np.nan],
    'salary': [50000, 60000, np.nan, np.nan],
    'department': ['HR', 'IT', np.nan, 'Finance']
}

# %%
new_df =pd.DataFrame(data)

# %%
print(new_df)
# Out:
#     age   salary department
# 0  25.0  50000.0         HR
# 1   NaN  60000.0         IT
# 2  30.0      NaN        NaN
# 3   NaN      NaN    Finance

# %%
new_df.fillna(0,inplace=True)

# %%
df.dtypes
# Out:
# age           float64
# department     object
# experience    float64
# dtype: object
