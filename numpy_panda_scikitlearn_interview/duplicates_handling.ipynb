# %%
import pandas as pd

data = {
    'name': ['Alice', 'Bob', 'Alice', 'Charlie', 'Bob'],
    'age': [25, 30, 25, 35, 30],
    'city': ['NY', 'LA', 'NY', 'SF', 'LA']
}

df = pd.DataFrame(data)

print(df)
# Out:
#       name  age city
# 0    Alice   25   NY
# 1      Bob   30   LA
# 2    Alice   25   NY
# 3  Charlie   35   SF
# 4      Bob   30   LA

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df.drop_duplicates(inplace=True)

# %%
print(df)
# Out:
#       name  age city
# 0    Alice   25   NY
# 1      Bob   30   LA
# 3  Charlie   35   SF
