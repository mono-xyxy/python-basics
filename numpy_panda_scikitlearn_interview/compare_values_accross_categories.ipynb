# %%
import pandas as pd

data = {
    'department': ['HR', 'IT', 'HR', 'IT', 'Finance', 'Finance'],
    'salary': [40000, 60000, 45000, 65000, 50000, 52000]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   department  salary
# 0         HR   40000
# 1         IT   60000
# 2         HR   45000
# 3         IT   65000
# 4    Finance   50000
# 5    Finance   52000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(x='department',y='salary', data = df)
plt.show()

# %%
sns.barplot(x='department',y='salary', data = df)
plt.show()

# %%
# x = category, y = numeric
