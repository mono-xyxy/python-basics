# %%
import numpy as np

# %%
a=np.array([1,2,3])

# %%
a.shape
# Out:
# (3,)

# %%
a.reshape(3,1)
# Out:
# array([[1],
#        [2],
#        [3]])

# %%
a[0]
# Out:
# np.int64(1)

# %%
a[1:3]
# Out:
# array([2, 3])

# %%
print(np.mean(a))
# Out:
# 2.0

# %%
print(np.sum(a))
# Out:
# 6

# %%
print(np.std(a))
# Out:
# 0.816496580927726

# %%
np.where(a>1,1,0)
# Out:
# array([0, 1, 1])

# %% [markdown]
# a[a>1]
