# %% [markdown]
# # What is a datatype?
# # Defines what kind of value variable holds and what operations you can perform on it

# %%
x = 10         # int
y=3.14         # float
name = "Ezzu"  #string

# %% [markdown]
# # types of data
# # numeric types:
#  `int is whole numbers`
#  `float is decimal numbers`
#  `complex is real plus imaginary`

# %%
a=5
b=2.5
c=3+4j

# %%
#can perform operations on variables now
print(a+b)   # addition
print(a**2)  # power
# Out:
# 7.5
# 25

# %% [markdown]
# # String (str) are immutable sequence of characters

# %%
s="Hello"
print(s[0])  # H
print(s[-1]) # o
print(s[1:4])# ell
# Out:
# H
# o
# ell

# %%
s="Hello"
s.lower()
s.upper()
s = s.replace("H","J")  # strings are immutable
print(s)
# Out:
# Jello

# %% [markdown]
# # Boolean (bool) used heavily in :
# - conditions
# - filtering data
# - ml pipelines

# %%
is_valid=True
print(5>3)
# Out:
# True

# %% [markdown]
# # List (Mutable)
# - ordered
# - mutable
# - allowed duplicates

# %%
nums = [1,2,3,4]

# %%
nums.append(10)
nums[0]=10
nums
# Out:
# [10, 2, 3, 4, 5, 10]

# %% [markdown]
# # Tuple (immutable) They are faster than lists and cannot modify

# %%
t=(1,2,3)

# %%
# t[0]=5 error

# %% [markdown]
# # Set (Unique values)

# %%
s={1,2,3,3}
print(s)
# Out:
# {1, 2, 3}

# %%
a={1,2,3}
b={2,3,4}

print(a & b) # intersection
print(a | b) # union
# Out:
# {2, 3}
# {1, 2, 3, 4}

# %% [markdown]
# # Dictionary (Key Value)

# %%
person = {
    "name":"Ezzu",
    "age": 23
}

# %%
print(person["name"])
person["age"]=30
print(person["age"])
person["gender"]="female"
print(person)
# Out:
# Ezzu
# 30
# {'name': 'Ezzu', 'age': 30, 'gender': 'female'}

# %% [markdown]
# # Type checking and conversion

# %%
x = 10
print(type(x))
# Out:
# <class 'int'>

# %%
print(int("5"))
print(float(10))
print(str(100))
print(list("abc"))
# Out:
# 5
# 10.0
# 100
# ['a', 'b', 'c']

# %% [markdown]
# - Lists → datasets, batches
# - Dictionaries → JSON, APIs, ML features
# - Strings → NLP tasks
# - Sets → deduplication
# - Booleans → filtering logic
