# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
nums = [10,20,30]
for i in nums:
    print(i)
# Out:
# 10
# 20
# 30

# %%
for char in "AI":
    print(char)
# Out:
# A
# I

# %% [markdown]
# range(start, stop, step)

# %%
for i in range(1,10,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
