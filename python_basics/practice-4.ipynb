# %%
x = "10"
y = int(x)
print(y)
print(type(y))
# Out:
# 10
# <class 'int'>

# %%
int("10")
int(3.7)
# int("abc")
# Out:
# 3

# %%
float(3.14)
float(5)
# Out:
# 5.0

# %%
str(100)
str(3.5)
# Out:
# '3.5'

# %%
list("abx")
# Out:
# ['a', 'b', 'x']

# %%
tuple([1,2,3])
# Out:
# (1, 2, 3)

# %%
set([1,2,2])
# Out:
# {1, 2}

# %%
pairs = [("a",1),("b",2)]
d=dict(pairs)
print(d)
# Out:
# {'a': 1, 'b': 2}

# %%
s = "1 2 3"
nums = list(map(int,s.split()))
print(nums)
# Out:
# [1, 2, 3]

# %%
nums = [1,2,3]
s = " ".join(map(str,nums))
print(s)
# Out:
# 1 2 3

# %%
print(bool(1))
print(bool(0))
print(bool(""))
print(bool("hi"))
# Out:
# True
# False
# False
# True

# %%
# 0, 0.0, "", [], {}, set(), None

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = input("Enter numbers: ")
del list
list = list(map(int,s.split()))
print(list)
print(sum(list))
# Out:
# [1, 2, 3]
# 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = ["1","2","3","4"]
list_int = list(map(int,data))
print(list_int)
list_sq = []
for i in list_int:
    list_sq.append(i*i)
list_sq = list(map(str,list_sq))
print(list_sq)
# Out:
# [1, 2, 3, 4]
# ['1', '4', '9', '16']
