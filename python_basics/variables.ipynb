# %%
# python variable
# a label pointing to data in memory
x=10
name="veda"
pi=3.14
#no type declaration needed python is dynamically typed

# %%
# core data types
# Integer(int)
a=10
b=-5

#Float(float)
x=3.14
y=-0.99

#string (str)
greet = "Hello"
name="veda"

# Boolean(bool)
is_active=True
is_done=False

# %%
# Store and print values
name = "Veda"
age = 22
print("Name: ",name)
print("Age: ",age)
# Out:
# Name:  Veda
# Age:  22

# %%
# Swap two variables
a=5
b=10
a,b = b,a
print(a,b)
# Out:
# 10 5

# %%
# take input and print
name = input("Enter your name: ")
print("Hello",name)
# Out:
# Hello veda

# %%
# Simple calculator
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))

print("Sum: ",a+b)
print("Product",a*b)
# Out:
# Sum:  5
# Product 4

# %%
# Area of circle
radius = 5
pi=3.14
area = pi*radius*radius
print("Area",area)
# Out:
# Area 78.5

# %%
celsius = 30
farenheit = (celsius* 9/5)+32
print(farenheit)
# Out:
# 86.0

# %%
# total marks and average
m1 = 80
m2 = 90
m3 = 85
total = m1+m2+m3
average = total / 3
print("Total: ",total)
print("Average",average)
# Out:
# Total:  255
# Average 85.0
